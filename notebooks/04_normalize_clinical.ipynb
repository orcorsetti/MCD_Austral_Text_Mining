# %% [markdown]
# # 04 — Normalización Clínica
#
# Normalización de terminología médica con **scispaCy** y mapeo a ontologías estándar.
#
# **Objetivos:**
# - Estandarizar condiciones clínicas (Condition, Keyword)
# - Mapeo a MeSH (Medical Subject Headings) con UMLS
# - Enriquecimiento del texto antes de embeddear:
#   - Expansión de abreviaturas (`eGFR` → `estimated glomerular filtration rate`)
#   - Tags semánticos: `[lab value]`, `[medication]`, `[demographics]`
#   - Prefijo de contexto del estudio
#
# **Input:** DataFrame parseado del notebook 03
# **Output:** DataFrame enriquecido listo para embedding
