# %% [markdown]
# # 05 — Generación de Embeddings
#
# Generación de embeddings para cada criterio individual de inclusión y exclusión.
#
# **Modelo principal:** `neuml/pubmedbert-base-embeddings`
# **Alternativas a evaluar:**
# - `pritamdeka/S-PubMedBert-MS-MARCO`
# - `BAAI/bge-small-en-v1.5`
# - `all-MiniLM-L6-v2`
#
# **Granularidad:** 1 embedding por criterio individual (no por bloque completo)
# → Permite explicabilidad fina: identificar exactamente qué criterio matchea
#
# **Input:** DataFrame enriquecido del notebook 04
# **Output:** Arrays de embeddings + metadata estructurada
