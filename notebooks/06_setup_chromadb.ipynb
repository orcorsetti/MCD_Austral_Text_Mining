# %% [markdown]
# # 06 — Configuración de ChromaDB
#
# Setup y configuración del vector store **ChromaDB** con persistencia local.
#
# **Objetivos:**
# - Inicializar `PersistentClient` en `./chroma_db/`
# - Crear dos colecciones separadas con `hnsw:space = cosine`:
#   - `inclusion_criteria`
#   - `exclusion_criteria`
# - Definir esquema de metadata por documento:
#   `nct_id`, `tipo`, `min_age`, `max_age`, `sex`, `status`, `condition`, `parse_status`
# - Verificar inserción de muestra y query de prueba
# - Benchmarkear tiempos de inserción y búsqueda
#
# **Input:** —
# **Output:** `chroma_db/` inicializada y lista para carga
