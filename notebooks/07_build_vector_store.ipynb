# %% [markdown]
# # 07 — Carga del Vector Store
#
# Inserción masiva de embeddings en **ChromaDB** (colecciones inclusión y exclusión).
#
# **Objetivos:**
# - Cargar embeddings del notebook 05 en batch
# - Insertar metadata de filtros duros junto a cada vector
# - Validar integridad: conteo de documentos por colección
# - Probar pre-filtering con `where` (edad, sexo, status) dentro de la query vectorial
#
# **Input:** Embeddings (nb05) + ChromaDB configurada (nb06)
# **Output:** ChromaDB poblada con todos los criterios indexados
