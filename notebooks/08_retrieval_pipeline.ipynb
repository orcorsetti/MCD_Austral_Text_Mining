# %% [markdown]
# # 08 — Pipeline de Retrieval (Online)
#
# Implementación del pipeline completo de consulta para un perfil de paciente.
#
# **Pasos:**
# 1. Recepción y embedding del formulario del paciente
# 2. Filtros duros vía `where` en ChromaDB (edad, sexo, status, ECOG)
# 3. Búsqueda semántica contra colección inclusión → top 50
# 4. Penalización por exclusión semántica (similitud alta → descartar)
# 5. Reranking con cross-encoder:
#    - `score_match − α × score_conflict`
#    - Modelos: `cross-encoder/ms-marco-MiniLM-L-6-v2`, `pritamdeka/PubMedBERT-MNLI-MedNLI`
# 6. Scoring compuesto: `w1 × score_reranker + w2 × score_geográfico`
# 7. Selección Top-N
#
# **Input:** Perfil paciente (texto libre) + ChromaDB poblada
# **Output:** Lista ordenada de ensayos candidatos con scores
